# %% [markdown]
# # Asynchronous Programming
#
# ## Definitions
# - **Parallelism**
#     - consists of performing multiple operations at the same time
# - **Multiprocessing**
#     - prattical application of parallelism
#     - it entails spreading tasks over a computer’s central processing units (CPUs, or cores)
# Concurrency is a slightly broader term than parallelism. It suggests that multiple tasks have the ability to run in an overlapping manner
#
# - **Asynchrony**: occurrence of events independent of main program flow.
#    - It means single-threaded application can handle multiple concurrent
#     operations by interleaving them.

# %% [markdown]
# - coroutines: computer program components that generalize subroutines to work in non-preemptive multitasking way by allowing execution to be suspended and resumed

# %%
async def fun():
    print("Main Async")

# %% [markdown]
#   - `main` is wrapped in `coroutine` object:

# %%
print(fun())
# Out:
# <coroutine object fun at 0x10a3d4280>
# /var/folders/l7/czl99vwd5615ws4dkjt03_8c0000gn/T/ipykernel_13426/2404915123.py:1: RuntimeWarning: coroutine 'fun' was never awaited
#   print(fun())
# ...

# %% [markdown]
# - **Async Event Loop**
#   - Construct that dispatches events
#   - it runs awaiting coroutines

# %%
#  # This function always creates a new event loop and closes it at the end.
# It should be used as a main entry point for asyncio programs, 
# and should ideally only be called once.
